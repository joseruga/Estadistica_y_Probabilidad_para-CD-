# %% [markdown]
# <a href="https://colab.research.google.com/github/joseruga/Estadistica_y_Probabilidad_para-CD-/blob/main/Semana2/Notebooks/Gausianas_Multivariadas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
medias = [172, 68]
covarianza = [[11, 9], [9, 10]]

altura, peso = np.random.multivariate_normal(mean = medias, 
                                             cov = covarianza, 
                                             size = 10000).T

sns.jointplot(x=altura, y=peso, kind = 'scatter', color = 'darkcyan', s = 2)
plt.show()

# %%
np.mean(altura)
# Out:
# 172.02273359202556

# %% [markdown]
# # Variables en Regresión

# %%
# Variables en regresión 
n = 10000
x2  = np.random.normal(loc=5, scale=1.2, size = n)
y2 = 6 - 2 * x2 + np.random.normal(size=n)


sns.jointplot(x=x2, y= y2, kind = 'scatter', color = 'darkcyan', s = 2 )
M_covarianza2 = np.cov(x2, y2)
print(M_covarianza2.round(2))
plt.show()
# Out:
# [[ 1.47 -2.94]
#  [-2.94  6.87]]

# %%
medias = [3, 16]
#Dos variabbles normales no estan relacionadas
covarianza =[[10, 0], [0, 4]]
rv1, rv2 = np.random.multivariate_normal(mean = medias, cov = covarianza, size = n).T
sns.jointplot(x=rv1, y= rv2, kind = 'scatter', color = 'darkcyan', s = 2 )

# %% [markdown]
# # Generación de vectores en más de dos dimensiones

# %%
import pandas as pd

# %%
medias = [-3, 6, 0]
covarianza =[[10, 4, -2], [4, 5, -1], [-2, -1, 7]]
rv1, rv2, rv3 = np.random.multivariate_normal(mean = medias, cov = covarianza, size = n).T
datos = pd.DataFrame({'Variable1': rv1, 'Variable2':rv2, 'Variable3':rv3})
datos
# Out:
#       Variable1  Variable2  Variable3
# 0     -2.029369   7.648789  -1.485628
# 1     -0.570172   5.399821  -0.945488
# 2     -5.582695   4.282285   1.591805
# 3     -3.159497   2.003624  -3.207551
# 4     -1.470603   5.360714  -2.321308
# ...         ...        ...        ...
# 9995  -5.992519   4.153272  -4.137824
# 9996  -4.143398   4.042002   5.418400
# 9997  -0.313632   7.031418  -2.134189
# 9998  -2.801793   6.924981   0.607382
# 9999  -4.500669   7.201097   3.319558
#
# [10000 rows x 3 columns]

# %%
sns.jointplot(data= datos, x='Variable1',  y='Variable2', kind = 'scatter', color = 'darkcyan', s = 2 )
plt.show()
